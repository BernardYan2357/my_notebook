# %% [markdown]
# # TensorBoard
#
# TensorBoard 是一个可视化工具，主要用于展示训练过程中的各种指标和模型结构。在 PyTorch 中，我们可以使用 `torch.utils.tensorboard` 模块来集成 TensorBoard 功能

# %%
from torch.utils.tensorboard import SummaryWriter 
# SummaryWriter 是 TensorBoard 的核心类，用于记录训练过程中的各种指标和模型结构
